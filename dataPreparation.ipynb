# %%
import pandas as pd
pcast_path = "/Users/amarkanaka/Documents/pcast_test.xlsx"
baker_path = "/Users/amarkanaka/Desktop/server_baker_files_final"

# %%
pcast_df = pd.read_excel(pcast_path)
pcast_df.head()
# Out:
#    Asset ID              Quartex UniqueIdentifier Quartex Name  \
# 0    266404  6ccc3880-63b2-4b06-ae3f-e86ff875452d    pcast0001
# 1    266405  61af38e3-1692-4121-b245-c52d2848f67b    pcast0005
# 2    266406  1227dae8-2cb7-487a-9815-de50492a1f9a    pcast0003
# 3    266407  4c4edf2b-8dd9-4cd3-8148-ec7b0b8b842e    pcast0004
# 4    266408  0530c901-140c-46c1-82b2-e68c3e96d37c    pcast0002
#
#                                        Collection(s)  \
# 0  PCAST reports|Barack Obama Science Policy Coll...
# 1  PCAST reports|Barack Obama Science Policy Coll...
# 2  PCAST reports|Barack Obama Science Policy Coll...
# 3  PCAST reports|Barack Obama Science Policy Coll...
# 4  PCAST reports|Barack Obama Science Policy Coll...
#
#                                        Published URL  \
# 0  digitalcollections.rice.edu/documents/detail/r...
# 1  digitalcollections.rice.edu/documents/detail/r...
# 2  digitalcollections.rice.edu/documents/detail/r...
# 3  digitalcollections.rice.edu/documents/detail/r...
# 4  digitalcollections.rice.edu/documents/detail/r...
#
#                                                Title  \
# 0  Report to the President on U.S. Preparations f...
# 1  Report to the President Realizing the Full Pot...
# 2  Report to the President and Congress Designing...
# 3  Report to the President Prepare and Inspire: K...
# 4  Report to the President on Accelerating the Pa...
#
#                             People and Organizations Location  \
# 0  Lander, Eric S.|Varmus, Harold|President's Cou...      NaN
# 1  Mundie, Craig|Cassel, Christine K. (Christine ...      NaN
# 2  Lazowska, Edward D.|Shaw, David E.|President's...      NaN
# 3  Lander, Eric S.|Gates, S. James, Jr., 1950-|Pr...      NaN
# 4  Savitz, Maxine|Moniz, Ernest J.|President's Co...      NaN
#
#   Approximate Date Abstract  ... University Archives Time Span Date Digital  \
# 0              NaN      NaN  ...                 NaN     2000s       2021.0
# 1              NaN      NaN  ...                 NaN     2010s       2021.0
# 2              NaN      NaN  ...                 NaN     2010s       2021.0
# 3              NaN      NaN  ...                 NaN     2010s       2021.0
# 4              NaN      NaN  ...                 NaN     2010s       2021.0
#
#                          Digitization Specifications  \
# 0  This asset is born digital. It may not have a ...
# 1  This asset is born digital. It may not have a ...
# 2  This asset is born digital. It may not have a ...
# 3  This asset is born digital. It may not have a ...
# 4  This asset is born digital. It may not have a ...
#
#                       Original Handle Rights Summary Accessibility Feature  \
# 0  https://hdl.handle.net/1911/112990  Public domain             taggedPDF
# 1  https://hdl.handle.net/1911/112994  Public domain             taggedPDF
# 2  https://hdl.handle.net/1911/112992  Public domain             taggedPDF
# 3  https://hdl.handle.net/1911/112993  Public domain             taggedPDF
# 4  https://hdl.handle.net/1911/112991  Public domain             taggedPDF
#
#   Accessibility Summary                                    Legacy Subjects  \
# 0                   NaN  United States. President (2009-2017 : Obama)|H...
# 1                   NaN  United States. President (2009-2017 : Obama)|I...
# 2                   NaN  United States. President (2009-2017 : Obama)|C...
# 3                   NaN  United States. President (2009-2017 : Obama)|S...
# 4                   NaN  United States. President (2009-2017 : Obama)|E...
#
#   Related Agencies and Organizations
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
# [5 rows x 32 columns]
